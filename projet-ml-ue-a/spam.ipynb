# %% [markdown]
# Librairies à importer

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_selection import SelectFromModel
from sklearn.metrics import (
    confusion_matrix, ConfusionMatrixDisplay,
    classification_report, f1_score, recall_score, accuracy_score
)
import models
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import TensorDataset, DataLoader

# %% [markdown]
# Obtention des données

# %%
X_train, X_test, y_train, y_test = models.preprocess_spam_data("spambase/spambase.data")
# Out:
# Total NaN Spambase : 0

# %% [markdown]
# Logistic Regression

# %%
models.logistic_regression_model(X_train, X_test, y_train, y_test)
# Out:
# F1-score Train : 0.91
# F1-score Test  : 0.92
#
# Classification Report - Test :
#
#               precision    recall  f1-score   support
#
#            0       0.96      0.94      0.95       506
#            1       0.91      0.94      0.92       336
#
#     accuracy                           0.94       842
#    macro avg       0.93      0.94      0.93       842
# weighted avg       0.94      0.94      0.94       842

# %% [markdown]
# KNN model

# %%
models.KNN_model_dataset1(X_train, X_test, y_train, y_test)
# Out:
# === SPAMBASE ===
# Meilleurs paramètres SPAM : {'metric': 'manhattan', 'n_neighbors': 11, 'weights': 'distance'}
# Accuracy (SPAM): 0.9263657957244655
#
# Classification report (SPAM):
#                precision    recall  f1-score   support
#
#            0       0.91      0.98      0.94       506
#            1       0.96      0.85      0.90       336
#
#     accuracy                           0.93       842
#    macro avg       0.93      0.91      0.92       842
# weighted avg       0.93      0.93      0.93       842
#
# Matrice de confusion (SPAM):
# [[495  11]
#  [ 51 285]]
# ROC-AUC (SPAM): 0.9771933229813665

# %% [markdown]
# Random forest model

# %%
models.random_forest_model(X_train, X_test, y_train, y_test)
# Out:
# Best threshold : 0.456
# Accuracy : 0.9430
# F1-score (classe 1) : 0.9290
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.96      0.95      0.95       506
#            1       0.92      0.93      0.93       336
#
#     accuracy                           0.94       842
#    macro avg       0.94      0.94      0.94       842
# weighted avg       0.94      0.94      0.94       842
# (RandomForestClassifier(n_estimators=250, random_state=42),
#  np.float64(0.45641025641025645))

# %% [markdown]
# MLP model

# %%
models.MLP_pytorch_model(X_train, X_test, y_train, y_test)
# Out:
# Ratio négatif/positif: 1.507818317200298
# Epoch [10/1000], Loss: 0.6760
# Epoch [20/1000], Loss: 0.6635
# Epoch [30/1000], Loss: 0.6591
# Epoch [40/1000], Loss: 0.6565
# Epoch [50/1000], Loss: 0.6549
# Epoch [60/1000], Loss: 0.6537
# Epoch [70/1000], Loss: 0.6529
# Epoch [80/1000], Loss: 0.6523
# Epoch [90/1000], Loss: 0.6517
# Epoch [100/1000], Loss: 0.6512
# Epoch [110/1000], Loss: 0.6506
# Epoch [120/1000], Loss: 0.6500
# Epoch [130/1000], Loss: 0.6494
# Epoch [140/1000], Loss: 0.6490
# Epoch [150/1000], Loss: 0.6486
# Epoch [160/1000], Loss: 0.6483
# Epoch [170/1000], Loss: 0.6481
# Epoch [180/1000], Loss: 0.6478
# Epoch [190/1000], Loss: 0.6476
# Epoch [200/1000], Loss: 0.6474
# Epoch [210/1000], Loss: 0.6472
# Epoch [220/1000], Loss: 0.6470
# Epoch [230/1000], Loss: 0.6469
# Epoch [240/1000], Loss: 0.6467
# Epoch [250/1000], Loss: 0.6466
# Epoch [260/1000], Loss: 0.6464
# Epoch [270/1000], Loss: 0.6463
# Epoch [280/1000], Loss: 0.6462
# Epoch [290/1000], Loss: 0.6460
# ...

# %% [markdown]
# Au final, parmi l’ensemble des modèles testés sur le dataset Spambase, le Random Forest apparaît comme la solution la plus performante offrant le meilleur équilibre entre accuracy, recall et F1-score. La régression logistique se positionne juste derrière : elle reste un excellent modèle de référence, très stable, rapide. Le KNN, bien que performant, montre ses limites sur des données de haute dimension, tandis que le MLP, plus complexe, n'apporte pas d'amélioration notable sans un réglage approfondi. Ainsi, pour ce type de données et pour un objectif de classification le Random Forest est le choix le plus pertinent.
